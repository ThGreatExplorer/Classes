# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
P = np.matrix([[0,1],[1,0]])

# %%
P**7
# Out:
# matrix([[0, 1],
#         [1, 0]])

# %%
import networkx as nx

# %%
P = np.zeros((5,5))

# %%
P[0,0] = .5
P[0,1] = .5
P[1,2] = 1
P[2,3] = 1
P[3,4] = 1
P[4,1] = 1

# %%
# Visualize the Markov Chain
G = nx.DiGraph()

# Add edges with probabilities as weights
for i in range(5):
    for j in range(5):
        if P[i, j] > 0:
            G.add_edge(i, j, weight=P[i, j])

# Draw the graph
pos = nx.spring_layout(G, seed=42)  # Layout for better visualization
edge_labels = {(i, j): f"{P[i, j]:.2f}" for i, j in G.edges}

plt.figure(figsize=(10, 8))
nx.draw(G, pos, with_labels=True, node_size=700, node_color="lightblue", font_size=12, font_weight="bold", arrowsize=20)
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10)
plt.title("Markov Chain period 3 and 2 intercommunicating classes")
plt.show()
